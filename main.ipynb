# %% [markdown]
# ## CODE COMPLEXITY CALCULATOR
# ### Introduction & File Upload

# %%
import ast
file_path = "test_files/all_features.py"
with open(file_path,'r') as file:
    code = file.read()
tree = ast.parse(code)

# %%
from analyzer import CodeAnalyzer
analyzer = CodeAnalyzer()
analyzer.visit(tree)

print("📦 File analyzed:", file_path)
print("Functions:", analyzer.functions)
print("Loops (for/while):", analyzer.loops)
print("Conditionals (if/else):", analyzer.ifs)
# Out:
# 📦 File analyzed: test_files/all_features.py
# Functions: 3
# Loops (for/while): 2
# Conditionals (if/else): 4

# %%
import ast
from analyzer import CodeAnalyzer

file_path = "test_files/factorial_recursion.py"

with open(file_path, "r") as f:
    source_code = f.read()

tree = ast.parse(source_code)
analyzer = CodeAnalyzer()
analyzer.visit(tree)

print("📦 File analyzed:", file_path)
print("Functions:", analyzer.functions)
print("Loops (for/while):", analyzer.loops)
print("Conditionals (if/else):", analyzer.ifs)

if analyzer.recursive_functions:
    print("🌀 Recursive Function(s):", ", ".join(analyzer.recursive_functions))
else:
    print("🧘 No recursion detected.")
# Out:
# 📦 File analyzed: test_files/factorial_recursion.py
# Functions: 1
# Loops (for/while): 0
# Conditionals (if/else): 2
# 🌀 Recursive Function(s): factorial

# %%
import ast
from analyzer import CodeAnalyzer

file_path = "test_files/factorial_recursion.py"

with open(file_path, "r") as f:
    source_code = f.read()

tree = ast.parse(source_code)
analyzer = CodeAnalyzer()
analyzer.visit(tree)

print("📦 File analyzed:", file_path)
print("Functions:", analyzer.functions)
print("Loops (for/while):", analyzer.loops)
print("Conditionals (if/else):", analyzer.ifs)
print("📐 Max Nesting Depth:", analyzer.max_depth)


if analyzer.recursive_functions:
    print("🌀 Recursive Function(s):", ", ".join(analyzer.recursive_functions))
else:
    print("🧘 No recursion detected.")
# Out:
# 📦 File analyzed: test_files/factorial_recursion.py
# Functions: 1
# Loops (for/while): 0
# Conditionals (if/else): 2
# 📐 Max Nesting Depth: 2
# 🌀 Recursive Function(s): factorial

# %%
import matplotlib.pyplot as plt
# Data
labels = ['Functions', 'Loops', 'Ifs', 'Max Nesting Depth']
values = [analyzer.functions, analyzer.loops, analyzer.ifs, analyzer.max_depth]

# Plot
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, values, color='skyblue', edgecolor='black')
plt.title("📊 Code Complexity Visualization")
plt.ylabel("Count")

# Add value labels on bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.1, int(yval), ha='center', va='bottom')

plt.ylim(0, max(values) + 2)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15316\148395874.py:19: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\OneDrive\Desktop\Code Complexity Calculator\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Lenovo\OneDrive\Desktop\Code Complexity Calculator\.venv\Scripts\python.exe

# %%
import os 
import ast
from analyzer import CodeAnalyzer
folder_path = "test_files"

for filename in os.listdir(folder_path):
    if filename.endswith(".py"):
        filepath =os.path.join(folder_path, filename)
        with open(filepath, "r", encoding = "utf-8") as f:
            source_code = f.read()

        tree = ast.parse(source_code)
        analyzer = CodeAnalyzer()
        analyzer.visit(tree)

        print(f"\n📦 File: {filename}")
        print("Functions:", analyzer.functions)
        print("Loops:", analyzer.loops)
        print("Ifs:", analyzer.ifs)
        print("Recursive Functions:", ", ".join(analyzer.recursive_functions) if analyzer.recursive_functions else "None")
        print("Max Nesting Depth:", analyzer.max_depth)
# Out:
# 📦 File: all_features.py
# Functions: 3
# Loops: 2
# Ifs: 4
# Recursive Functions: fib
# Max Nesting Depth: 3
#
# 📦 File: factorial_recursion.py
# Functions: 1
# Loops: 0
# Ifs: 2
# Recursive Functions: factorial
# Max Nesting Depth: 2
#
# 📦 File: loop_and_conditions.py
# Functions: 1
# Loops: 4
# Ifs: 2
# Recursive Functions: None
# Max Nesting Depth: 3
#
# 📦 File: multiple_functions.py
# Functions: 3
# Loops: 0
# Ifs: 0
# Recursive Functions: None
# Max Nesting Depth: 1
#
# 📦 File: nested_structure.py
# Functions: 1
# Loops: 2
# Ifs: 4
# Recursive Functions: None
# Max Nesting Depth: 4

# %%
import os
import ast
from analyzer import CodeAnalyzer
import matplotlib.pyplot as plt

folder_path = "test_files"
file_names = []
functions_list = []
loops_list = []
ifs_list = []
depths_list = []

# Analyze all .py files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".py"):
        filepath = os.path.join(folder_path, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            source_code = f.read()

        tree = ast.parse(source_code)
        analyzer = CodeAnalyzer()
        analyzer.visit(tree)

        file_names.append(filename)
        functions_list.append(analyzer.functions)
        loops_list.append(analyzer.loops)
        ifs_list.append(analyzer.ifs)
        depths_list.append(analyzer.max_depth)

        # Print individual report
        print(f"\n📦 File: {filename}")
        print("Functions:", analyzer.functions)
        print("Loops:", analyzer.loops)
        print("Ifs:", analyzer.ifs)
        print("Recursive Functions:", ", ".join(analyzer.recursive_functions) if analyzer.recursive_functions else "None")
        print("Max Nesting Depth:", analyzer.max_depth)
# Out:
# 📦 File: all_features.py
# Functions: 3
# Loops: 2
# Ifs: 4
# Recursive Functions: fib
# Max Nesting Depth: 3
#
# 📦 File: factorial_recursion.py
# Functions: 1
# Loops: 0
# Ifs: 2
# Recursive Functions: factorial
# Max Nesting Depth: 2
#
# 📦 File: loop_and_conditions.py
# Functions: 1
# Loops: 4
# Ifs: 2
# Recursive Functions: None
# Max Nesting Depth: 3
#
# 📦 File: multiple_functions.py
# Functions: 3
# Loops: 0
# Ifs: 0
# Recursive Functions: None
# Max Nesting Depth: 1
#
# 📦 File: nested_structure.py
# Functions: 1
# Loops: 2
# Ifs: 4
# Recursive Functions: None
# Max Nesting Depth: 4

# %%
import numpy as np

x = np.arange(len(file_names))  # label positions
width = 0.2  # width of each bar

plt.figure(figsize=(12, 6))

plt.bar(x - 1.5*width, functions_list, width, label='Functions', color='skyblue')
plt.bar(x - 0.5*width, loops_list, width, label='Loops', color='lightgreen')
plt.bar(x + 0.5*width, ifs_list, width, label='Ifs', color='salmon')
plt.bar(x + 1.5*width, depths_list, width, label='Nesting Depth', color='orange')

plt.xticks(x, file_names, rotation=45)
plt.ylabel("Count")
plt.title("📊 Code Complexity Comparison")
plt.legend()
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15316\3024443654.py:17: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\OneDrive\Desktop\Code Complexity Calculator\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
import ast
import matplotlib.pyplot as plt
from analyzer import CodeAnalyzer

# 🔢 Complexity score calculator
def calculate_complexity_score(functions, loops, ifs, depth, is_recursive):
    score = 0
    score += functions * 2      # 2 points per function
    score += loops * 3          # 3 points per loop
    score += ifs * 2            # 2 points per if/else
    score += depth * 1          # 1 point per nesting level
    if is_recursive:
        score += 5              # 5 bonus for recursion
    return score

# %%
# Folder containing your Python files
folder_path = "test_files"

# Store results
file_names = []
scores = []
difficulties = []

# Loop through all files
for filename in os.listdir(folder_path):
    if filename.endswith(".py"):
        filepath = os.path.join(folder_path, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            source = f.read()

        # Parse and analyze
        tree = ast.parse(source)
        analyzer = CodeAnalyzer()
        analyzer.visit(tree)

        # Score calculation
        is_recursive = bool(analyzer.recursive_functions)
        score = calculate_complexity_score(
            analyzer.functions,
            analyzer.loops,
            analyzer.ifs,
            analyzer.max_depth,
            is_recursive
        )

        # Difficulty level
        if score <= 10:
            level = "🟢 Easy"
        elif score <= 20:
            level = "🟡 Medium"
        else:
            level = "🔴 Hard"

        # Print summary
        print(f"\n📦 {filename}")
        print("Functions:", analyzer.functions)
        print("Loops:", analyzer.loops)
        print("Ifs:", analyzer.ifs)
        print("Recursive:", ", ".join(analyzer.recursive_functions) if is_recursive else "None")
        print("Nesting Depth:", analyzer.max_depth)
        print("🔢 Complexity Score:", score)
        print("🎯 Difficulty Level:", level)

        # Save for chart
        file_names.append(filename)
        scores.append(score)
        difficulties.append(level)
# Out:
# 📦 all_features.py
# Functions: 3
# Loops: 2
# Ifs: 4
# Recursive: fib
# Nesting Depth: 3
# 🔢 Complexity Score: 28
# 🎯 Difficulty Level: 🔴 Hard
#
# 📦 factorial_recursion.py
# Functions: 1
# Loops: 0
# Ifs: 2
# Recursive: factorial
# Nesting Depth: 2
# 🔢 Complexity Score: 13
# 🎯 Difficulty Level: 🟡 Medium
#
# 📦 loop_and_conditions.py
# Functions: 1
# Loops: 4
# Ifs: 2
# Recursive: None
# Nesting Depth: 3
# 🔢 Complexity Score: 21
# 🎯 Difficulty Level: 🔴 Hard
#
# 📦 multiple_functions.py
# Functions: 3
# Loops: 0
# Ifs: 0
# Recursive: None
# Nesting Depth: 1
# 🔢 Complexity Score: 7
# 🎯 Difficulty Level: 🟢 Easy
#
# 📦 nested_structure.py
# Functions: 1
# Loops: 2
# Ifs: 4
# Recursive: None
# Nesting Depth: 4
# 🔢 Complexity Score: 20
# 🎯 Difficulty Level: 🟡 Medium
#
# 📦 score.py
# Functions: 1
# Loops: 0
# Ifs: 4
# Recursive: calculate_complexity_score
# Nesting Depth: 2
# 🔢 Complexity Score: 17
# 🎯 Difficulty Level: 🟡 Medium

# %%
# Plot file scores
plt.figure(figsize=(10, 5))
bars = plt.bar(file_names, scores, color='salmon', edgecolor='black')
plt.xlabel("File")
plt.ylabel("Complexity Score")
plt.title("📊 Code Complexity Score by File")

# Annotate with difficulty labels
for bar, label in zip(bars, difficulties):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, label, ha='center', va='bottom')

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15316\2126191381.py:14: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15316\2126191381.py:14: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15316\2126191381.py:14: UserWarning: Glyph 128993 (\N{LARGE YELLOW CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15316\2126191381.py:14: UserWarning: Glyph 128994 (\N{LARGE GREEN CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\OneDrive\Desktop\Code Complexity Calculator\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import streamlit as st
import ast
from analyzer import CodeAnalyzer

st.title("🧠 Code Complexity Analyzer")

# ✅ THIS LINE defines uploaded_files
uploaded_files = st.file_uploader("Upload Python files", type="py", accept_multiple_files=True)

report_data = []

for file in uploaded_files:
    source_code = file.read().decode("utf-8")
    tree = ast.parse(source_code)
    
    analyzer = CodeAnalyzer()
    analyzer.visit(tree)

    is_recursive = bool(analyzer.recursive_functions)

    score = (
        analyzer.functions * 2 +
        analyzer.loops * 3 +
        analyzer.ifs * 2 +
        analyzer.max_depth +
        (5 if is_recursive else 0)
    )

    report_data.append({
        "Filename": file.name,  # ✅ Fix is here!
        "Functions": analyzer.functions,
        "Loops": analyzer.loops,
        "Ifs": analyzer.ifs,
        "Recursion": "Yes" if is_recursive else "No",
        "Nesting Depth": analyzer.max_depth,
        "Score": score,
        "Difficulty": "Easy" if score <= 10 else "Medium" if score <= 20 else "Hard"
    })
# Out:
# 2025-07-01 12:31:25.285 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 12:31:25.816
# ...
#   command:
#
#     streamlit run c:\Users\Lenovo\OneDrive\Desktop\Code Complexity Calculator\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-07-01 12:31:25.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 12:31:25.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 12:31:25.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 12:31:25.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import csv
with open("code_scores.csv", "w", newline="",encoding="utf-8") as csvfile:
    fieldnames = ["Filename", "Functions", "Loops", "Ifs", "Recursion", "Nesting Depth", "Score", "Difficulty"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for data in report_data:
        writer.writerow(data)
    print("✅ Results exported to code_scores.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#       5 writer.writeheader()
# ----> 6 for data in report_data:
#       7     writer.writerow(data)
#       8 print("✅ Results exported to code_scores.csv")
#
# NameError: name 'report_data' is not defined
